# %% [markdown]
# <a href="https://colab.research.google.com/github/mwithgod3952/TIL/blob/main/CHAHE_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'
    ITALIC = '\x1B'

# %%
from google.colab import drive; drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os 
wd_pth = '/content/drive/MyDrive/CLAHE'
os.chdir(wd_pth)

if os.getcwd() == wd_pth:
    print(f'\n\t {wd_pth}')
else:
    print('')
# Out:
# 	 /content/drive/MyDrive/CLAHE

# %%
import cv2
from skimage import io
from matplotlib import pyplot as plt

# %%
img_pth = f"{wd_pth}/{[x for x in os.listdir(wd_pth) if x.endswith('jpeg')][0]}"
# gray scale = 1
img = cv2.imread(img_pth, 1)

plt.figure( figsize=(3, 3) )
plt.imshow(img)
plt.show()

# %%
Lab_img = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
L, a, b = cv2.split(Lab_img)

# %% [markdown]
# <font size = 5><font color = 'blue'>**---**</font>

# %% [markdown]
# <font size = 2>테스트를 위해 'luminosity'에 대한 값만을 'equalization ( 균등화 )'을 통해 stretching한 결과를 살펴본다.</font>

# %%
plt.figure( figsize=(3, 3) )

# ***
org_dist, cvt_dist, vis = plt.hist(L.flat, 
                                   bins=100, 
                                   range=(0,255),
                                   color='grey')
# ***

plt.show()

# %%
plt.figure( figsize=(3, 3) )

# ***
equ_org_dist, equ_cvt_dist, _vis = plt.hist(cv2.equalizeHist(L).flat, 
                                   bins=100, 
                                   range=(0,255),
                                   color='black')
# ***

print(f'{equ_org_dist}{color.END} \n')
plt.show()
# Out:
# [27078.  1512.   644.   665.   722.   743.   774.   943.     0.  1267.
#    664.   695.     0.  1557.   876.   730.   842.     0.   926.  1292.
#      0.     0.     0.  2680.     0.  1423.     0.  1913.     0.     0.
#      0.     0.  3259.     0.  1679.     0.     0.     0.  3211.     0.
#   1541.     0.     0.     0.  3009.     0.  1288.     0.     0.  2464.
#      0.     0.  2016.     0.  1220.     0.  1796.     0.  1791.     0.
#   1482.     0.  1465.   701.     0.  1228.  1037.   916.     0.   967.
#   1313.     0.  1515.     0.   709.   960.  1226.     0.  1328.   741.
#    439.  1274.   378.  1205.   537.   964.   448.   876.   420.   975.
#    889.   720.   882.   570.   992.   600.   866.   603.   894.   740.]

# %% [markdown]
# <font size = 2>'Histogram-equalization'의 목적대로 'contrast'에 대한 pixel's intensity가 조정되었지만 원지않는 noise들이 생성됨을 확인할 수 있다. 너무 밝거나 너무 어두운 부분이 이에 해당한다. 이 정도를 제한하기 위한 목적으로 'contrast limiting'과정이 요구된다.</font>

# %%
plt.figure( figsize=(3,3) )
plt.imshow(cv2.equalizeHist(L), cmap='gray')
plt.show()

# %% [markdown]
# <font size = 5><font color = 'blue'>**---**</font>

# %% [markdown]
# <font size = 4>***CLAHE***</font>

# %%
# HE
_Updated_LAB_img = cv2.merge( (cv2.equalizeHist(L), a, b) )
HE_RGB_img = cv2.cvtColor(_Updated_LAB_img, cv2.COLOR_LAB2BGR)

# CLAHE
CLAHE = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
CLAHE_img = CLAHE.apply(L)
Updated_LAB_img = cv2.merge( (CLAHE_img, a, b) )
CLAHE_RGB_img = cv2.cvtColor(Updated_LAB_img, cv2.COLOR_LAB2BGR) 

cvt_img_info = [HE_RGB_img, CLAHE_RGB_img]
_cvt_img_info = ['HE', 'CLAHE']
plt.figure(figsize = (6, 3))
for i in range(1, 3):
    j=i-1
    plt.subplot(1, 2, i)
    img = cvt_img_info[j]
    plt.title(_cvt_img_info[j])
    plt.imshow(img)
